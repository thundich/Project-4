# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.linear_model import LogisticRegression
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import distutils as _distutils
import tensorflow as tf
import tensorflow.compat.v1 as tf
from sklearn.metrics import balanced_accuracy_score, confusion_matrix, classification_report

# %%
# Import and read the cleaned_state_market_tracker.csv.
import pandas as pd 
market_df = pd.read_csv("../Resources/cleaned_state_market_tracker.csv")
market_df.head()
# Out:
#    Unnamed: 0  table_id          state state_code            property_type  \
# 0           0        25         Hawaii         HI                Townhouse
# 1           1         6       Nebraska         NE  Multi-Family (2-4 Unit)
# 2           2        42       Virginia         VA              Condo/Co-op
# 3           3        21        Georgia         GA          All Residential
# 4           4        10  New Hampshire         NH                Townhouse
#
#    property_type_id  median_sale_price  median_list_price  median_ppsf  \
# 0                13             776200           485000.0        484.0
# 1                 4             109800           138500.0         56.0
# 2                 3             275700           440600.0        264.0
# 3                -1             237100           254800.0        117.0
# 4                13             200000           262300.0        135.0
#
#    median_list_ppsf  homes_sold  pending_sales  new_listings  inventory  \
# 0             398.0          16           10.0          10.0       76.0
# 1              80.0          15           13.0          33.0      125.0
# 2             258.0        1256         1140.0        1521.0     2712.0
# 3             125.0       11366         9352.0       12986.0    50603.0
# 4             148.0         173          141.0         105.0      442.0
#
#    months_of_supply  avg_sale_to_list  sold_above_list parent_metro_region  \
# 0               4.8          1.002073         0.312500         West Region
# 1               8.3          0.916258         0.133333      Midwest Region
# 2               2.2          0.994101         0.308121        South Region
# 3               4.5          0.976470         0.178075        South Region
# 4               2.6          0.981605         0.277457    Northeast Region
#
#    year  month
# 0  2019     12
# 1  2012      8
# 2  2020     10
# 3  2019     11
# 4  2017     11

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
market_df.drop(columns = ['table_id','property_type_id', 'state_code', 'median_ppsf', "median_list_ppsf", "sold_above_list", "year", "months_of_supply", "state", "parent_metro_region"], inplace=True)
market_df
# Out:
#        Unnamed: 0              property_type  median_sale_price  \
# 0               0                  Townhouse             776200
# 1               1    Multi-Family (2-4 Unit)             109800
# 2               2                Condo/Co-op             275700
# 3               3            All Residential             237100
# 4               4                  Townhouse             200000
# ...           ...                        ...                ...
# 35418       35418    Multi-Family (2-4 Unit)              77200
# 35419       35419  Single Family Residential             273000
# 35420       35420    Multi-Family (2-4 Unit)             236300
# 35421       35421                  Townhouse             373000
# 35422       35422            All Residential             635000
#
#        median_list_price  homes_sold  pending_sales  new_listings  inventory  \
# 0               485000.0          16           10.0          10.0       76.0
# 1               138500.0          15           13.0          33.0      125.0
# 2               440600.0        1256         1140.0        1521.0     2712.0
# 3               254800.0       11366         9352.0       12986.0    50603.0
# 4               262300.0         173          141.0         105.0      442.0
# ...                  ...         ...            ...           ...        ...
# 35418           137000.0         299          221.0         459.0     1829.0
# 35419           296600.0         138           59.0         197.0      940.0
# 35420           324500.0         226          236.0         485.0     1095.0
# 35421           460900.0         187          255.0         263.0      226.0
# 35422           641000.0        1022         1053.0        1288.0     1875.0
#
#        avg_sale_to_list  month
# 0              1.002073     12
# 1              0.916258      8
# 2              0.994101     10
# 3              0.976470     11
# 4              0.981605     11
# ...                 ...    ...
# 35418          0.926174      5
# 35419          0.973945      2
# 35420          0.995301      7
# 35421          1.007853      1
# 35422          1.013034      3
#
# [35423 rows x 10 columns]

# %%
null_market_df = market_df.dropna(how='any', axis= 0)
null_market_df
# Out:
#        Unnamed: 0              property_type  median_sale_price  \
# 0               0                  Townhouse             776200
# 1               1    Multi-Family (2-4 Unit)             109800
# 2               2                Condo/Co-op             275700
# 3               3            All Residential             237100
# 4               4                  Townhouse             200000
# ...           ...                        ...                ...
# 35418       35418    Multi-Family (2-4 Unit)              77200
# 35419       35419  Single Family Residential             273000
# 35420       35420    Multi-Family (2-4 Unit)             236300
# 35421       35421                  Townhouse             373000
# 35422       35422            All Residential             635000
#
#        median_list_price  homes_sold  pending_sales  new_listings  inventory  \
# 0               485000.0          16           10.0          10.0       76.0
# 1               138500.0          15           13.0          33.0      125.0
# 2               440600.0        1256         1140.0        1521.0     2712.0
# 3               254800.0       11366         9352.0       12986.0    50603.0
# 4               262300.0         173          141.0         105.0      442.0
# ...                  ...         ...            ...           ...        ...
# 35418           137000.0         299          221.0         459.0     1829.0
# 35419           296600.0         138           59.0         197.0      940.0
# 35420           324500.0         226          236.0         485.0     1095.0
# 35421           460900.0         187          255.0         263.0      226.0
# 35422           641000.0        1022         1053.0        1288.0     1875.0
#
#        avg_sale_to_list  month
# 0              1.002073     12
# 1              0.916258      8
# 2              0.994101     10
# 3              0.976470     11
# 4              0.981605     11
# ...                 ...    ...
# 35418          0.926174      5
# 35419          0.973945      2
# 35420          0.995301      7
# 35421          1.007853      1
# 35422          1.013034      3
#
# [34012 rows x 10 columns]

# %%
# Determine the number of unique values in each column.
category_values = null_market_df.nunique()
category_values
# Out:
# Unnamed: 0           34012
# property_type            5
# median_sale_price     6061
# median_list_price     5553
# homes_sold            8834
# pending_sales         7719
# new_listings          9472
# inventory            14159
# avg_sale_to_list     33875
# month                   12
# dtype: int64

# %%
# Split our preprocessed data into our features and target arrays
y = null_market_df["property_type"].astype('category').cat.codes
X = null_market_df.drop(["property_type"], axis=1)

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=55)
y
# Out:
# 0        4
# 1        2
# 2        1
# 3        0
# 4        4
#         ..
# 35418    2
# 35419    3
# 35420    2
# 35421    4
# 35422    0
# Length: 34012, dtype: int8

# %%
# Create a StandardScaler instances
scaler = MinMaxScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = len(X_train_scaled[0])

nn_model = tf.keras.models.Sequential()

hidden_nodes_layer1 = 4
hidden_nodes_layer2 = 4

# First hidden layer
nn_model.add(tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation='sigmoid'))

# Second hidden layer
nn_model.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation='sigmoid'))

# Output layer
nn_model.add(tf.keras.layers.Dense(units=1, activation= "sigmoid"))

# Check the structure of the model
nn_model.summary()

print(number_input_features)
# Out:
# c:\Python312\Lib\site-packages\keras\src\layers\core\dense.py:85: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 4)              │            40 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 4)              │            20 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │             5 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 65 (260.00 B)
#  Trainable params: 65 (260.00 B)
#  Non-trainable params: 0 (0.00 B)
# 9

# %%
# Compile the model
nn_model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn_model.fit(X_train_scaled,y_train, epochs=50)
# Out:
# Epoch 1/50
# c:\Python312\Lib\site-packages\keras\src\losses\losses.py:22: SyntaxWarning: In loss categorical_crossentropy, expected y_pred.shape to be (batch_size, num_classes) with num_classes > 1. Received: y_pred.shape=(None, 1). Consider using 'binary_crossentropy' if you only have 2 classes.
#   return self.fn(y_true, y_pred, **self._fn_kwargs)
# 798/798 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.2056 - loss: 0.0000e+00
# Epoch 2/50
# 798/798 ━━━━━━━━━━━━━━━━━━━━ 1s 932us/step - accuracy: 0.1962 - loss: 0.0000e+00
# Epoch 3/50
# 798/798 ━━━━━━━━━━━━━━━━━━━━ 1s 817us/step - accuracy: 0.2027 - loss: 0.0000e+00
# Epoch 4/50
# 798/798 ━━━━━━━━━━━━━━━━━━━━ 1s 894us/step - accuracy: 0.2029 - loss: 0.0000e+00
# Epoch 5/50
# 798/798 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.2029 - loss: 0.0000e+00
# Epoch 6/50
# 798/798 ━━━━━━━━━━━━━━━━━━━━ 1s 754us/step - accuracy: 0.1973 - loss: 0.0000e+00
# Epoch 7/50
# 798/798 ━━━━━━━━━━━━━━━━━━━━ 1s 910us/step - accuracy: 0.1996 - loss: 0.0000e+00
# Epoch 8/50
# 798/798 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.2004 - loss: 0.0000e+00
# Epoch 9/50
# 798/798 ━━━━━━━━━━━━━━━━━━━━ 1s 930us/step - accuracy: 0.1994 - loss: 0.0000e+00
# Epoch 10/50
# 798/798 ━━━━━━━━━━━━━━━━━━━━ 1s 984us/step - accuracy: 0.1978 - loss: 0.0000e+00
# Epoch 11/50
# 798/798 ━━━━━━━━━━━━━━━━━━━━ 1s 846us/step - accuracy: 0.2040 - loss: 0.0000e+00
# Epoch 12/50
# 798/798 ━━━━━━━━━━━━━━━━━━━━ 1s 944us/step - accuracy: 0.1989 - loss: 0.0000e+00
# Epoch 13/50
# 798/798 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.1952 - loss: 0.0000e+00
# Epoch 14/50
# 798/798 ━━━━━━━━━━━━━━━━━━━━ 1s 758us/step - accuracy: 0.1981 - loss: 0.0000e+00
# Epoch 15/50
# 798/798 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.2043 - loss: 0.0000e+00
# Epoch 16/50
# 798/798 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.1983 - loss: 0.0000e+00
# Epoch 17/50
# 798/798 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.1975 - loss: 0.0000e+00
# Epoch 18/50
# 798/798 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.2002 - loss: 0.0000e+00
# Epoch 19/50
# 798/798 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.2015 - loss: 0.0000e+00
# Epoch 20/50
# 798/798 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.1959 - loss: 0.0000e+00
# Epoch 21/50
# 798/798 ━━━━━━━━━━━━━━━━━━━━ 1s 828us/step - accuracy: 0.1937 - loss: 0.0000e+00
# Epoch 22/50
# 798/798 ━━━━━━━━━━━━━━━━━━━━ 1s 774us/step - accuracy: 0.1960 - loss: 0.0000e+00
# Epoch 23/50
# 798/798 ━━━━━━━━━━━━━━━━━━━━ 1s 821us/step - accuracy: 0.2010 - loss: 0.0000e+00
# Epoch 24/50
# 798/798 ━━━━━━━━━━━━━━━━━━━━ 1s 851us/step - accuracy: 0.2019 - loss: 0.0000e+00
# Epoch 25/50
# 798/798 ━━━━━━━━━━━━━━━━━━━━ 1s 978us/step - accuracy: 0.2004 - loss: 0.0000e+00
# Epoch 26/50
# 798/798 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.1991 - loss: 0.0000e+00
# Epoch 27/50
# 798/798 ━━━━━━━━━━━━━━━━━━━━ 1s 649us/step - accuracy: 0.1999 - loss: 0.0000e+00
# Epoch 28/50
# 798/798 ━━━━━━━━━━━━━━━━━━━━ 1s 948us/step - accuracy: 0.1965 - loss: 0.0000e+00
# Epoch 29/50
# 798/798 ━━━━━━━━━━━━━━━━━━━━ 1s 838us/step - accuracy: 0.1995 - loss: 0.0000e+00
# Epoch 30/50
# 798/798 ━━━━━━━━━━━━━━━━━━━━ 1s 896us/step - accuracy: 0.2020 - loss: 0.0000e+00
# Epoch 31/50
# 798/798 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.1936 - loss: 0.0000e+00
# Epoch 32/50
# 798/798 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.2008 - loss: 0.0000e+00
# Epoch 33/50
# 798/798 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.1992 - loss: 0.0000e+00
# Epoch 34/50
# 798/798 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.1999 - loss: 0.0000e+00
# Epoch 35/50
# 798/798 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.1983 - loss: 0.0000e+00
# Epoch 36/50
# 798/798 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.1963 - loss: 0.0000e+00
# Epoch 37/50
# 798/798 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.2020 - loss: 0.0000e+00
# Epoch 38/50
# 798/798 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.2003 - loss: 0.0000e+00
# Epoch 39/50
# 798/798 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.2006 - loss: 0.0000e+00
# Epoch 40/50
# 798/798 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.1989 - loss: 0.0000e+00
# Epoch 41/50
# 798/798 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.2007 - loss: 0.0000e+00
# Epoch 42/50
# 798/798 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.1997 - loss: 0.0000e+00
# Epoch 43/50
# 798/798 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.2007 - loss: 0.0000e+00
# Epoch 44/50
# 798/798 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.1966 - loss: 0.0000e+00
# Epoch 45/50
# 798/798 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.1988 - loss: 0.0000e+00
# Epoch 46/50
# 798/798 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.1975 - loss: 0.0000e+00
# Epoch 47/50
# 798/798 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.2046 - loss: 0.0000e+00
# Epoch 48/50
# 798/798 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.1988 - loss: 0.0000e+00
# Epoch 49/50
# 798/798 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.2006 - loss: 0.0000e+00
# Epoch 50/50
# 798/798 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.2002 - loss: 0.0000e+00

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 266/266 - 1s - 3ms/step - accuracy: 0.2004 - loss: 0.0000e+00
# Loss: 0.0, Accuracy: 0.20039986073970795
