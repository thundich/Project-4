# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.linear_model import LogisticRegression
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import distutils as _distutils
import tensorflow as tf
import tensorflow.compat.v1 as tf
from sklearn.metrics import balanced_accuracy_score, confusion_matrix, classification_report

# %%
# Import and read the cleaned_state_market_tracker.csv.
import pandas as pd 
market_df = pd.read_csv("cleaned_state_market_tracker.csv")
market_df.head()
# Out:
#    table_id    state state_code              property_type  property_type_id  \
# 0         1  Alabama         AL    Multi-Family (2-4 Unit)                 4
# 1         1  Alabama         AL                Condo/Co-op                 3
# 2         1  Alabama         AL                  Townhouse                13
# 3         1  Alabama         AL            All Residential                -1
# 4         1  Alabama         AL  Single Family Residential                 6
#
#    median_sale_price  median_list_price  median_ppsf  median_list_ppsf  \
# 0              61900           179000.0         27.0              95.0
# 1             363000           353700.0        388.0             185.0
# 2             130500           186400.0         83.0              95.0
# 3             191000           192400.0         97.0              98.0
# 4             138400           162100.0         72.0              86.0
#
#    homes_sold  pending_sales  new_listings  inventory  months_of_supply  \
# 0           4            3.0           3.0       15.0               3.8
# 1         281          230.0         286.0      902.0               3.2
# 2         116           61.0         120.0      430.0               3.7
# 3        5181         3033.0        5544.0    20941.0               4.0
# 4        2042          724.0        2815.0    13234.0               6.5
#
#    avg_sale_to_list  sold_above_list parent_metro_region  year  month  rei_id
# 0          0.900837         0.000000        South Region  2014      3       1
# 1          0.983281         0.135231        South Region  2023      7       2
# 2          0.962387         0.120690        South Region  2015      4       3
# 3          0.971602         0.182397        South Region  2017      6       4
# 4          0.950388         0.154750        South Region  2013      2       5

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
market_df.drop(columns = ['table_id','property_type_id', 'state_code', 'median_ppsf', "median_list_ppsf", "sold_above_list", "year", "state", "parent_metro_region"], inplace=True)
market_df
# Out:
#                    property_type  median_sale_price  median_list_price  \
# 0        Multi-Family (2-4 Unit)              61900           179000.0
# 1                    Condo/Co-op             363000           353700.0
# 2                      Townhouse             130500           186400.0
# 3                All Residential             191000           192400.0
# 4      Single Family Residential             138400           162100.0
# ...                          ...                ...                ...
# 35418    Multi-Family (2-4 Unit)             153500           244900.0
# 35419    Multi-Family (2-4 Unit)             141600           231700.0
# 35420  Single Family Residential             243700           249200.0
# 35421                  Townhouse              73800           143500.0
# 35422                Condo/Co-op             157700           153100.0
#
#        homes_sold  pending_sales  new_listings  inventory  months_of_supply  \
# 0               4            3.0           3.0       15.0               3.8
# 1             281          230.0         286.0      902.0               3.2
# 2             116           61.0         120.0      430.0               3.7
# 3            5181         3033.0        5544.0    20941.0               4.0
# 4            2042          724.0        2815.0    13234.0               6.5
# ...           ...            ...           ...        ...               ...
# 35418           9            8.0          14.0       33.0               3.7
# 35419           5            9.0          12.0       33.0               6.6
# 35420        1509         1505.0        1928.0     4627.0               3.1
# 35421          19            6.0          15.0       99.0               5.2
# 35422          24            5.0          32.0      222.0               9.3
#
#        avg_sale_to_list  month  rei_id
# 0              0.900837      3       1
# 1              0.983281      7       2
# 2              0.962387      4       3
# 3              0.971602      6       4
# 4              0.950388      2       5
# ...                 ...    ...     ...
# 35418          0.947979     10   35419
# 35419          0.941061      5   35420
# 35420          0.977123      4   35421
# 35421          0.944210     10   35422
# 35422          0.915664      7   35423
#
# [35423 rows x 11 columns]

# %%
null_market_df = market_df.dropna(how='any', axis= 0)
null_market_df
# Out:
#                    property_type  median_sale_price  median_list_price  \
# 0        Multi-Family (2-4 Unit)              61900           179000.0
# 1                    Condo/Co-op             363000           353700.0
# 2                      Townhouse             130500           186400.0
# 3                All Residential             191000           192400.0
# 4      Single Family Residential             138400           162100.0
# ...                          ...                ...                ...
# 35418    Multi-Family (2-4 Unit)             153500           244900.0
# 35419    Multi-Family (2-4 Unit)             141600           231700.0
# 35420  Single Family Residential             243700           249200.0
# 35421                  Townhouse              73800           143500.0
# 35422                Condo/Co-op             157700           153100.0
#
#        homes_sold  pending_sales  new_listings  inventory  months_of_supply  \
# 0               4            3.0           3.0       15.0               3.8
# 1             281          230.0         286.0      902.0               3.2
# 2             116           61.0         120.0      430.0               3.7
# 3            5181         3033.0        5544.0    20941.0               4.0
# 4            2042          724.0        2815.0    13234.0               6.5
# ...           ...            ...           ...        ...               ...
# 35418           9            8.0          14.0       33.0               3.7
# 35419           5            9.0          12.0       33.0               6.6
# 35420        1509         1505.0        1928.0     4627.0               3.1
# 35421          19            6.0          15.0       99.0               5.2
# 35422          24            5.0          32.0      222.0               9.3
#
#        avg_sale_to_list  month  rei_id
# 0              0.900837      3       1
# 1              0.983281      7       2
# 2              0.962387      4       3
# 3              0.971602      6       4
# 4              0.950388      2       5
# ...                 ...    ...     ...
# 35418          0.947979     10   35419
# 35419          0.941061      5   35420
# 35420          0.977123      4   35421
# 35421          0.944210     10   35422
# 35422          0.915664      7   35423
#
# [34012 rows x 11 columns]

# %%
# Determine the number of unique values in each column.
category_values = null_market_df.nunique()
category_values
# Out:
# property_type            5
# median_sale_price     6061
# median_list_price     5553
# homes_sold            8834
# pending_sales         7719
# new_listings          9472
# inventory            14159
# months_of_supply       223
# avg_sale_to_list     33875
# month                   12
# rei_id               34012
# dtype: int64

# %%
# Split our preprocessed data into our features and target arrays
y = null_market_df["property_type"].astype('category').cat.codes
X = null_market_df.drop(["property_type"], axis=1)

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=55)
y
# Out:
# 0        2
# 1        1
# 2        4
# 3        0
# 4        3
#         ..
# 35418    2
# 35419    2
# 35420    3
# 35421    4
# 35422    1
# Length: 34012, dtype: int8

# %%
# Create a StandardScaler instances
scaler = MinMaxScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = len(X_train_scaled[0])

nn_model = tf.keras.models.Sequential()

hidden_nodes_layer1 = 4
hidden_nodes_layer2 = 4
hidden_nodes_layer3= 1 

# First hidden layer
nn_model.add(tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation='relu'))

# Second hidden layer
nn_model.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation='relu'))

# Output layer
nn_model.add(tf.keras.layers.Dense(units=1, activation= "sigmoid"))

# Check the structure of the model
nn_model.summary()

print(number_input_features)
# Out:
# c:\Python312\Lib\site-packages\keras\src\layers\core\dense.py:85: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 4)              │            44 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 4)              │            20 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │             5 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 69 (276.00 B)
#  Trainable params: 69 (276.00 B)
#  Non-trainable params: 0 (0.00 B)
# 10

# %%
# Compile the model
nn_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn_model.fit(X_train_scaled,y_train, epochs=50)
# Out:
# Epoch 1/50
# 798/798 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.2000 - loss: -8.1124
# Epoch 2/50
# 798/798 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.2020 - loss: -254.0736
# Epoch 3/50
# 798/798 ━━━━━━━━━━━━━━━━━━━━ 1s 919us/step - accuracy: 0.1924 - loss: -1234.7642
# Epoch 4/50
# 798/798 ━━━━━━━━━━━━━━━━━━━━ 1s 912us/step - accuracy: 0.1967 - loss: -3154.6790
# Epoch 5/50
# 798/798 ━━━━━━━━━━━━━━━━━━━━ 1s 948us/step - accuracy: 0.2002 - loss: -6183.3750
# Epoch 6/50
# 798/798 ━━━━━━━━━━━━━━━━━━━━ 1s 983us/step - accuracy: 0.1981 - loss: -10438.4814
# Epoch 7/50
# 798/798 ━━━━━━━━━━━━━━━━━━━━ 1s 924us/step - accuracy: 0.1999 - loss: -16246.2861
# Epoch 8/50
# 798/798 ━━━━━━━━━━━━━━━━━━━━ 1s 946us/step - accuracy: 0.1975 - loss: -22893.8203
# Epoch 9/50
# 798/798 ━━━━━━━━━━━━━━━━━━━━ 1s 981us/step - accuracy: 0.1957 - loss: -31999.7598
# Epoch 10/50
# 798/798 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.2017 - loss: -40924.3828
# Epoch 11/50
# 798/798 ━━━━━━━━━━━━━━━━━━━━ 1s 878us/step - accuracy: 0.1927 - loss: -54130.2070
# Epoch 12/50
# 798/798 ━━━━━━━━━━━━━━━━━━━━ 1s 921us/step - accuracy: 0.2030 - loss: -66288.8672
# Epoch 13/50
# 798/798 ━━━━━━━━━━━━━━━━━━━━ 1s 883us/step - accuracy: 0.2008 - loss: -83721.6562
# Epoch 14/50
# 798/798 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.1952 - loss: -100849.4453
# Epoch 15/50
# 798/798 ━━━━━━━━━━━━━━━━━━━━ 1s 959us/step - accuracy: 0.1968 - loss: -121025.3594
# Epoch 16/50
# 798/798 ━━━━━━━━━━━━━━━━━━━━ 1s 896us/step - accuracy: 0.1981 - loss: -143368.9531
# Epoch 17/50
# 798/798 ━━━━━━━━━━━━━━━━━━━━ 1s 848us/step - accuracy: 0.1935 - loss: -165819.0938
# Epoch 18/50
# 798/798 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.1969 - loss: -193628.7188
# Epoch 19/50
# 798/798 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.2011 - loss: -221136.3594
# Epoch 20/50
# 798/798 ━━━━━━━━━━━━━━━━━━━━ 1s 845us/step - accuracy: 0.2013 - loss: -251888.5312
# Epoch 21/50
# 798/798 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.2002 - loss: -285546.5938
# Epoch 22/50
# 798/798 ━━━━━━━━━━━━━━━━━━━━ 1s 880us/step - accuracy: 0.2018 - loss: -330275.5312
# Epoch 23/50
# 798/798 ━━━━━━━━━━━━━━━━━━━━ 1s 985us/step - accuracy: 0.2016 - loss: -369069.5312
# Epoch 24/50
# 798/798 ━━━━━━━━━━━━━━━━━━━━ 1s 835us/step - accuracy: 0.2028 - loss: -407530.1562
# Epoch 25/50
# 798/798 ━━━━━━━━━━━━━━━━━━━━ 1s 795us/step - accuracy: 0.1985 - loss: -463036.4688
# Epoch 26/50
# 798/798 ━━━━━━━━━━━━━━━━━━━━ 1s 896us/step - accuracy: 0.1979 - loss: -508965.1250
# Epoch 27/50
# 798/798 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.1967 - loss: -564912.3125
# Epoch 28/50
# 798/798 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.1992 - loss: -618003.1250
# Epoch 29/50
# 798/798 ━━━━━━━━━━━━━━━━━━━━ 1s 925us/step - accuracy: 0.1970 - loss: -682789.9375
# Epoch 30/50
# 798/798 ━━━━━━━━━━━━━━━━━━━━ 1s 979us/step - accuracy: 0.2002 - loss: -737294.0625
# Epoch 31/50
# 798/798 ━━━━━━━━━━━━━━━━━━━━ 1s 946us/step - accuracy: 0.1929 - loss: -815907.0000
# Epoch 32/50
# 798/798 ━━━━━━━━━━━━━━━━━━━━ 1s 945us/step - accuracy: 0.1997 - loss: -878577.0000
# Epoch 33/50
# 798/798 ━━━━━━━━━━━━━━━━━━━━ 1s 941us/step - accuracy: 0.1985 - loss: -956084.4375
# Epoch 34/50
# 798/798 ━━━━━━━━━━━━━━━━━━━━ 1s 882us/step - accuracy: 0.1983 - loss: -1044926.2500
# Epoch 35/50
# 798/798 ━━━━━━━━━━━━━━━━━━━━ 1s 855us/step - accuracy: 0.1998 - loss: -1123910.8750
# Epoch 36/50
# 798/798 ━━━━━━━━━━━━━━━━━━━━ 1s 920us/step - accuracy: 0.1998 - loss: -1213782.1250
# Epoch 37/50
# 798/798 ━━━━━━━━━━━━━━━━━━━━ 1s 899us/step - accuracy: 0.2001 - loss: -1296212.1250
# Epoch 38/50
# 798/798 ━━━━━━━━━━━━━━━━━━━━ 1s 898us/step - accuracy: 0.1959 - loss: -1435761.0000
# Epoch 39/50
# 798/798 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.1989 - loss: -1492187.2500
# Epoch 40/50
# 798/798 ━━━━━━━━━━━━━━━━━━━━ 1s 926us/step - accuracy: 0.2004 - loss: -1588067.3750
# Epoch 41/50
# 798/798 ━━━━━━━━━━━━━━━━━━━━ 1s 949us/step - accuracy: 0.2023 - loss: -1687130.6250
# Epoch 42/50
# 798/798 ━━━━━━━━━━━━━━━━━━━━ 1s 827us/step - accuracy: 0.1996 - loss: -1857626.5000
# Epoch 43/50
# 798/798 ━━━━━━━━━━━━━━━━━━━━ 1s 851us/step - accuracy: 0.2001 - loss: -1988699.6250
# Epoch 44/50
# 798/798 ━━━━━━━━━━━━━━━━━━━━ 1s 919us/step - accuracy: 0.1988 - loss: -2093304.3750
# Epoch 45/50
# 798/798 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.1999 - loss: -2195145.7500
# Epoch 46/50
# 798/798 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.2002 - loss: -2342671.5000
# Epoch 47/50
# 798/798 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.2003 - loss: -2474494.0000
# Epoch 48/50
# 798/798 ━━━━━━━━━━━━━━━━━━━━ 1s 952us/step - accuracy: 0.1981 - loss: -2664251.5000
# Epoch 49/50
# 798/798 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.1993 - loss: -2812287.5000
# Epoch 50/50
# 798/798 ━━━━━━━━━━━━━━━━━━━━ 1s 942us/step - accuracy: 0.1971 - loss: -2982843.2500

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 266/266 - 0s - 1ms/step - accuracy: 0.2019 - loss: -2.9689e+06
# Loss: -2968912.0, Accuracy: 0.2019287347793579
